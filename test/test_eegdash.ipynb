# %%
from braindecode.datasets import EEGDashDataset
# %load_ext autoreload
# %autoreload 2

# %%
# ds = EEGDashDataset('ds005505')
ds = EEGDashDataset('ds005672')
# Out:
# /Users/dtyoung/Documents/mnt/nemar-test/openneuro/ds005672
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 2
#       1 # ds = EEGDashDataset('ds005505')
# ----> 2 ds = EEGDashDataset('ds005672')
#
# File ~/Documents/Research/braindecode/braindecode/datasets/eegdash.py:43, in EEGDashDataset.__init__(self, dataset_name, subject_ids, dataset_kwargs, dataset_load_kwargs)
#      36 def __init__(
#      37     self,
#      38     dataset_name: str,
#    (...)
#      41     dataset_load_kwargs: dict[str, Any] | None = None,
#      42 ):
# ---> 43     bids_dataset = BIDSDataset(data_dir=f'/Users/dtyoung/Documents/mnt/nemar-test/openneuro/{dataset_name}', dataset=dataset_name)
#      44     all_base_ds = []
#      45     for f in bids_dataset.get_files():
#
# File ~/Documents/Research/braindecode/braindecode/datasets/eegdash.py:68, in BIDSDataset.__init__(self, data_dir, dataset, raw_format)
#      66 print(data_dir)
#      67 if data_dir is None or not os.path.exists(data_dir):
# ---> 68     raise ValueError('data_dir must be specified and must exist')
#      69 self.bidsdir = Path(data_dir)
#      70 self.dataset = dataset
#
# ValueError: data_dir must be specified and must exist

# %%
from braindecode.preprocessing import create_fixed_length_windows
